# %%
# !unzip "/content/futbol players.v7-raw-images.yolov8.zip" -d /content/futbol_dataset #unzipping dataset
# Out:
# Archive:  /content/futbol players.v7-raw-images.yolov8.zip
#  extracting: /content/futbol_dataset/README.dataset.txt
#  extracting: /content/futbol_dataset/README.roboflow.txt
#  extracting: /content/futbol_dataset/data.yaml
#    creating: /content/futbol_dataset/test/
#    creating: /content/futbol_dataset/test/images/
#  extracting: /content/futbol_dataset/test/images/1-fps-2_00001_jpeg_jpg.rf.e95412d81fb5fe6dd2b3fb120b41ba1a.jpg
#  extracting: /content/futbol_dataset/test/images/1-fps-2_00014_jpeg_jpg.rf.a2541cb929e1b22719488740b5a0ad1f.jpg
#  extracting: /content/futbol_dataset/test/images/1-fps-2_00022_jpeg_jpg.rf.81c5748a3929ba5040542c0e6fe39057.jpg
#  extracting: /content/futbol_dataset/test/images/1-fps-2_00025_jpeg_jpg.rf.3573cdee6c723239c508947693536769.jpg
#  extracting: /content/futbol_dataset/test/images/1-fps-2_00032_jpeg_jpg.rf.b296b14a819c31e356d452a2a6cb3520.jpg
# ...

# %%
# !pip install --upgrade ultralytics

from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 116.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
model=YOLO('yolov8n.pt')                           #importing and training model on custom dataset
model.train(data="/content/futbol_dataset/data.yaml",epochs=50)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 113MB/s]
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image, display
display(Image(filename='/content/runs/detect/train/results.png', width=800))

# %%
display(Image(filename='/content/runs/detect/train/val_batch0_pred.jpg', width=800))

# %%
model = YOLO('runs/detect/train/weights/best.pt')
metrics = model.val(data='/content/futbol_dataset/data.yaml')
print(metrics.results_dict)
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 496.5±191.2 MB/s, size: 26.8 KB)
# val: Scanning /content/futbol_dataset/valid/labels.cache... 33 images, 0 backgrounds, 0 corrupt: 100%|██████████| 33/33 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
#                    all         33        407       0.96      0.849      0.915      0.543
#                 futbol         28         28      0.996      0.643      0.772      0.312
#                 player         33        359      0.974      0.955       0.99      0.644
#               referree         20         20      0.909       0.95      0.983      0.673
# Speed: 0.2ms preprocess, 16.3ms inference, 0.0ms loss, 3.2ms postprocess per image
# ...

# %%
model = YOLO("yolo11n.pt", task="detect")
results = model.predict(source="/content/football.jpg", save=True)
# Out:
# image 1/1 /content/football.jpg: 384x640 13 persons, 12.9ms
# Speed: 3.1ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict

# %%
display(Image(filename='/content/runs/detect/predict/football.jpg', width=800))
# Out:
# <generator object BasePredictor.stream_inference at 0x79b655c88280>

# %%
model = YOLO("runs/detect/train/weights/best.pt")  # Load your trained model

results = model.predict(
    source="/content/video_football.mp4",
    stream=False,     # Process whole video at once
    save=True,
    show=False        # Avoid GUI popups in Colab
)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/392) /content/video_football.mp4: 640x384 1 futbol, 2 players, 38.8ms
# video 1/1 (frame 2/392) /content/video_football.mp4: 640x384 1 futbol, 3 players, 9.2ms
# video 1/1 (frame 3/392) /content/video_football.mp4: 640x384 1 futbol, 3 players, 8.6ms
# video 1/1 (frame 4/392) /content/video_football.mp4: 640x384 3 players, 9.1ms
# ...
